# %% [markdown]
# # Exploratory Data Analysis (EDA) - IPTU Data
#
# This notebook explores all IPTU (property tax) data files:
# - CSV files for years 2020-2023
# - JSON file for year 2024
#
# We will load all files, examine their schemas, and perform basic data exploration.

# %%
import pandas as pd
import json
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 1. Load CSV Files (2020-2023)

# %%
# Define file paths
csv_files = {
    2020: 'data/iptu_2020/iptu_2020.csv',
    2021: 'data/iptu_2021/iptu_2021.csv',
    2022: 'data/iptu_2022/iptu_2022.csv',
    2023: 'data/iptu_2023/iptu_2023.csv'
}

# Dictionary to store dataframes
dataframes = {}

print("Loading CSV files...")
for year, file_path in csv_files.items():
    print(f"\nLoading {year} data from {file_path}...")
    try:
        # CSV files use semicolon as delimiter
        df = pd.read_csv(file_path, sep=';', encoding='utf-8', low_memory=False)
        dataframes[year] = df
        print(f"✓ Loaded {year}: {len(df):,} rows, {len(df.columns)} columns")
        print(f"  Memory usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
    except Exception as e:
        print(f"✗ Error loading {year}: {str(e)}")

print(f"\n✓ Successfully loaded {len(dataframes)} CSV files")
# Out:
# Loading CSV files...
#
# Loading 2020 data from data/iptu_2020/iptu_2020.csv...
# ✓ Loaded 2020: 403,915 rows, 32 columns
#   Memory usage: 834.43 MB
#
# Loading 2021 data from data/iptu_2021/iptu_2021.csv...
# ✓ Loaded 2021: 407,245 rows, 32 columns
#   Memory usage: 841.34 MB
#
# Loading 2022 data from data/iptu_2022/iptu_2022.csv...
# ✓ Loaded 2022: 411,090 rows, 32 columns
#   Memory usage: 849.32 MB
#
# Loading 2023 data from data/iptu_2023/iptu_2023.csv...
# ✓ Loaded 2023: 415,029 rows, 32 columns
#   Memory usage: 857.52 MB
#
# ✓ Successfully loaded 4 CSV files

# %% [markdown]
# ## 2. Print Schemas for All CSV Files

# %%
print("=" * 80)
print("SCHEMAS FOR ALL CSV FILES")
print("=" * 80)

for year in sorted(dataframes.keys()):
    df = dataframes[year]
    print(f"\n{'='*80}")
    print(f"SCHEMA FOR IPTU {year}")
    print(f"{'='*80}")
    print(f"Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")
    print(f"\nColumn Names and Data Types:")
    print("-" * 80)
    
    schema_info = pd.DataFrame({
        'Column': df.columns,
        'Data Type': df.dtypes,
        'Non-Null Count': df.count(),
        'Null Count': df.isnull().sum(),
        'Null Percentage': (df.isnull().sum() / len(df) * 100).round(2)
    })
    
    print(schema_info.to_string(index=False))
    print(f"\n")
# Out:
# ================================================================================
# SCHEMAS FOR ALL CSV FILES
# ================================================================================
#
# ================================================================================
# SCHEMA FOR IPTU 2020
# ================================================================================
# Shape: 403,915 rows × 32 columns
#
# Column Names and Data Types:
# --------------------------------------------------------------------------------
#                              Column Data Type  Non-Null Count  Null Count  Null Percentage
#              Número do contribuinte    object          403915           0              0.0
#                    ano do exercício     int64          403915           0              0.0
#               data do cadastramento    object          403915           0              0.0
#                tipo de contribuinte    object          403915           0              0.0
#  CPF/CNPJ mascarado do contribuinte    object          403915           0              0.0
#                          logradouro    object          403915           0              0.0
#                              numero     int64          403915           0              0.0
#                         complemento    object          403915           0              0.0
#                              bairro    object          403915           0              0.0
#                              cidade    object          403915           0              0.0
#                              estado    object          403915           0              0.0
#                        fração ideal    object          403915           0              0.0
#                        AREA TERRENO    object          403915           0              0.0
#                     AREA CONSTRUIDA    object          403915           0              0.0
#                        área ocupada    object          403915           0              0.0
#              valor do m2 do terreno    object          403915           0              0.0
#           valor do m2 de construção    object          403915           0              0.0
#         ano da construção corrigido     int64          403915           0              0.0
#            quantidade de pavimentos     int64          403915           0              0.0
#               tipo de uso do imóvel    object          403915           0              0.0
#        tipo de padrão da construção    object          403915           0              0.0
#              fator de obsolescência    object          403915           0              0.0
# ano e mês de início da contribuição     int64          403915           0              0.0
#      valor total do imóvel estimado    object          403915           0              0.0
#               valor cobrado de IPTU    object          403915           0              0.0
#                                 CEP     int64          403915           0              0.0
#        Regime de Tributação do iptu    object          403915           0              0.0
#        Regime de Tributação da trsd    object          403915           0              0.0
#                  Tipo de Construção    object          403915           0              0.0
#              Tipo de Empreendimento    object          403915           0              0.0
#                   Tipo de Estrutura    object          403915           0              0.0
#                   Código Logradouro     int64          403915           0              0.0
#
#
#
# ================================================================================
# SCHEMA FOR IPTU 2021
# ================================================================================
# Shape: 407,245 rows × 32 columns
#
# Column Names and Data Types:
# --------------------------------------------------------------------------------
#                              Column Data Type  Non-Null Count  Null Count  Null Percentage
#              Número do contribuinte    object          407245           0              0.0
#                    ano do exercício     int64          407245           0              0.0
#               data do cadastramento    object          407245           0              0.0
#                tipo de contribuinte    object          407245           0              0.0
#  CPF/CNPJ mascarado do contribuinte    object          407245           0              0.0
#                          logradouro    object          407245           0              0.0
#                              numero     int64          407245           0              0.0
#                         complemento    object          407245           0              0.0
#                              bairro    object          407245           0              0.0
#                              cidade    object          407245           0              0.0
#                              estado    object          407245           0              0.0
#                        fração ideal    object          407245           0              0.0
#                        AREA TERRENO    object          407245           0              0.0
#                     AREA CONSTRUIDA    object          407245           0              0.0
#                        área ocupada    object          407245           0              0.0
#              valor do m2 do terreno    object          407245           0              0.0
#           valor do m2 de construção    object          407245           0              0.0
#         ano da construção corrigido     int64          407245           0              0.0
#            quantidade de pavimentos     int64          407245           0              0.0
#               tipo de uso do imóvel    object          407245           0              0.0
#        tipo de padrão da construção    object          407245           0              0.0
#              fator de obsolescência    object          407245           0              0.0
# ano e mês de início da contribuição     int64          407245           0              0.0
#      valor total do imóvel estimado    object          407245           0              0.0
#               valor cobrado de IPTU    object          407245           0              0.0
#                                 CEP     int64          407245           0              0.0
#        Regime de Tributação do iptu    object          407245           0              0.0
#        Regime de Tributação da trsd    object          407245           0              0.0
#                  Tipo de Construção    object          407245           0              0.0
#              Tipo de Empreendimento    object          407245           0              0.0
#                   Tipo de Estrutura    object          407245           0              0.0
#                   Código Logradouro     int64          407245           0              0.0
#
#
#
# ================================================================================
# SCHEMA FOR IPTU 2022
# ================================================================================
# Shape: 411,090 rows × 32 columns
#
# Column Names and Data Types:
# --------------------------------------------------------------------------------
#                              Column Data Type  Non-Null Count  Null Count  Null Percentage
#              Número do contribuinte    object          411090           0              0.0
#                    ano do exercício     int64          411090           0              0.0
#               data do cadastramento    object          411090           0              0.0
#                tipo de contribuinte    object          411090           0              0.0
#  CPF/CNPJ mascarado do contribuinte    object          411090           0              0.0
#                          logradouro    object          411090           0              0.0
#                              numero     int64          411090           0              0.0
#                         complemento    object          411090           0              0.0
#                              bairro    object          411090           0              0.0
#                              cidade    object          411090           0              0.0
#                              estado    object          411090           0              0.0
#                        fração ideal    object          411090           0              0.0
#                        AREA TERRENO    object          411090           0              0.0
#                     AREA CONSTRUIDA    object          411090           0              0.0
#                        área ocupada    object          411090           0              0.0
#              valor do m2 do terreno    object          411090           0              0.0
#           valor do m2 de construção    object          411090           0              0.0
#         ano da construção corrigido     int64          411090           0              0.0
#            quantidade de pavimentos     int64          411090           0              0.0
#               tipo de uso do imóvel    object          411090           0              0.0
#        tipo de padrão da construção    object          411090           0              0.0
#              fator de obsolescência    object          411090           0              0.0
# ano e mês de início da contribuição     int64          411090           0              0.0
#      valor total do imóvel estimado    object          411090           0              0.0
#               valor cobrado de IPTU    object          411090           0              0.0
#                                 CEP     int64          411090           0              0.0
#        Regime de Tributação do iptu    object          411090           0              0.0
#        Regime de Tributação da trsd    object          411090           0              0.0
#                  Tipo de Construção    object          411090           0              0.0
#              Tipo de Empreendimento    object          411090           0              0.0
#                   Tipo de Estrutura    object          411090           0              0.0
#                   Código Logradouro     int64          411090           0              0.0
#
#
#
# ================================================================================
# SCHEMA FOR IPTU 2023
# ================================================================================
# Shape: 415,029 rows × 32 columns
#
# Column Names and Data Types:
# --------------------------------------------------------------------------------
#                              Column Data Type  Non-Null Count  Null Count  Null Percentage
#              Número do contribuinte    object          415029           0              0.0
#                    ano do exercício     int64          415029           0              0.0
#               data do cadastramento    object          415029           0              0.0
#                tipo de contribuinte    object          415029           0              0.0
#  CPF/CNPJ mascarado do contribuinte    object          415029           0              0.0
#                          logradouro    object          415029           0              0.0
#                              numero     int64          415029           0              0.0
#                         complemento    object          415029           0              0.0
#                              bairro    object          415029           0              0.0
#                              cidade    object          415029           0              0.0
#                              estado    object          415029           0              0.0
#                        fração ideal    object          415029           0              0.0
#                        AREA TERRENO    object          415029           0              0.0
#                     AREA CONSTRUIDA    object          415029           0              0.0
#                        área ocupada    object          415029           0              0.0
#              valor do m2 do terreno    object          415029           0              0.0
#           valor do m2 de construção    object          415029           0              0.0
#         ano da construção corrigido     int64          415029           0              0.0
#            quantidade de pavimentos     int64          415029           0              0.0
#               tipo de uso do imóvel    object          415029           0              0.0
#        tipo de padrão da construção    object          415029           0              0.0
#              fator de obsolescência    object          415029           0              0.0
# ano e mês de início da contribuição     int64          415029           0              0.0
#      valor total do imóvel estimado    object          415029           0              0.0
#               valor cobrado de IPTU    object          415029           0              0.0
#                                 CEP     int64          415029           0              0.0
#        Regime de Tributação do iptu    object          415029           0              0.0
#        Regime de Tributação da trsd    object          415029           0              0.0
#                  Tipo de Construção    object          415029           0              0.0
#              Tipo de Empreendimento    object          415029           0              0.0
#                   Tipo de Estrutura    object          415029           0              0.0
#                   Código Logradouro     int64          415029           0              0.0

# %% [markdown]
# ## 3. Load JSON File (2024)

# %%
json_file_path = 'data/iptu_2024_json/iptu_2024_json.json'

print(f"Loading JSON file: {json_file_path}")
print("=" * 80)

# First, let's read the JSON structure
with open(json_file_path, 'r', encoding='utf-8') as f:
    json_data = json.load(f)

# Extract schema information
print("\nJSON File Structure:")
print(f"Keys: {list(json_data.keys())}")

if 'fields' in json_data:
    print(f"\nNumber of fields: {len(json_data['fields'])}")
    print("\nField Definitions:")
    print("-" * 80)
    fields_df = pd.DataFrame(json_data['fields'])
    print(fields_df.to_string(index=False))

if 'records' in json_data:
    print(f"\nNumber of records: {len(json_data['records']):,}")

print("\nConverting JSON records to DataFrame...")
# Convert records to DataFrame
if 'records' in json_data and 'fields' in json_data:
    # Get column names from fields
    column_names = [field['id'] for field in json_data['fields']]
    
    # Create DataFrame from records
    df_2024 = pd.DataFrame(json_data['records'], columns=column_names)
    dataframes[2024] = df_2024
    
    print(f"✓ Loaded 2024: {len(df_2024):,} rows, {len(df_2024.columns)} columns")
    print(f"  Memory usage: {df_2024.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# Loading JSON file: data/iptu_2024_json/iptu_2024_json.json
# ================================================================================
#
# JSON File Structure:
# Keys: ['fields', 'records']
#
# Number of fields: 33
#
# Field Definitions:
# --------------------------------------------------------------------------------
#      type                                  id
#       int                                 _id
#      text              Número do contribuinte
#   numeric                    ano do exercício
# timestamp               data do cadastramento
#      text                tipo de contribuinte
#      text  CPF/CNPJ mascarado do contribuinte
#      text                          logradouro
#   numeric                              numero
#      text                         complemento
#      text                              bairro
#      text                              cidade
#      text                              estado
#      text                        fração ideal
#      text                        AREA TERRENO
#      text                     AREA CONSTRUIDA
#      text                        área ocupada
#      text              valor do m2 do terreno
#      text           valor do m2 de construção
#   numeric         ano da construção corrigido
#   numeric                    quant pavimentos
#      text               tipo de uso do imóvel
#      text        tipo de padrão da construção
#      text              fator de obsolescência
#   numeric ano e mês de início da contribuição
#      text      valor total do imóvel estimado
#      text                          valor IPTU
#   numeric                                 CEP
#      text        Regime de Tributação do iptu
#      text        Regime de Tributação da trsd
#      text                  Tipo de Construção
#      text              Tipo de Empreendimento
#      text                   Tipo de Estrutura
#   numeric                   Código Logradouro
#
# Number of records: 500
#
# Converting JSON records to DataFrame...
# ✓ Loaded 2024: 500 rows, 33 columns
#   Memory usage: 1.03 MB

# %% [markdown]
# ## 4. Print Schema for JSON File (2024)

# %%
if 2024 in dataframes:
    df_2024 = dataframes[2024]
    print("=" * 80)
    print("SCHEMA FOR IPTU 2024 (JSON)")
    print("=" * 80)
    print(f"Shape: {df_2024.shape[0]:,} rows × {df_2024.shape[1]} columns")
    print(f"\nColumn Names and Data Types:")
    print("-" * 80)
    
    schema_info = pd.DataFrame({
        'Column': df_2024.columns,
        'Data Type': df_2024.dtypes,
        'Non-Null Count': df_2024.count(),
        'Null Count': df_2024.isnull().sum(),
        'Null Percentage': (df_2024.isnull().sum() / len(df_2024) * 100).round(2)
    })
    
    print(schema_info.to_string(index=False))
    print(f"\n")
# Out:
# ================================================================================
# SCHEMA FOR IPTU 2024 (JSON)
# ================================================================================
# Shape: 500 rows × 33 columns
#
# Column Names and Data Types:
# --------------------------------------------------------------------------------
#                              Column Data Type  Non-Null Count  Null Count  Null Percentage
#                                 _id     int64             500           0              0.0
#              Número do contribuinte    object             500           0              0.0
#                    ano do exercício     int64             500           0              0.0
#               data do cadastramento    object             500           0              0.0
#                tipo de contribuinte    object             500           0              0.0
#  CPF/CNPJ mascarado do contribuinte    object             500           0              0.0
#                          logradouro    object             500           0              0.0
#                              numero     int64             500           0              0.0
#                         complemento    object             500           0              0.0
#                              bairro    object             500           0              0.0
#                              cidade    object             500           0              0.0
#                              estado    object             500           0              0.0
#                        fração ideal    object             500           0              0.0
#                        AREA TERRENO    object             500           0              0.0
#                     AREA CONSTRUIDA    object             500           0              0.0
#                        área ocupada    object             500           0              0.0
#              valor do m2 do terreno    object             500           0              0.0
#           valor do m2 de construção    object             500           0              0.0
#         ano da construção corrigido     int64             500           0              0.0
#                    quant pavimentos     int64             500           0              0.0
#               tipo de uso do imóvel    object             500           0              0.0
#        tipo de padrão da construção    object             500           0              0.0
#              fator de obsolescência    object             500           0              0.0
# ano e mês de início da contribuição     int64             500           0              0.0
#      valor total do imóvel estimado    object             500           0              0.0
#                          valor IPTU    object             500           0              0.0
#                                 CEP     int64             500           0              0.0
#        Regime de Tributação do iptu    object             500           0              0.0
#        Regime de Tributação da trsd    object             500           0              0.0
#                  Tipo de Construção    object             500           0              0.0
#              Tipo de Empreendimento    object             500           0              0.0
#                   Tipo de Estrutura    object             500           0              0.0
#                   Código Logradouro     int64             500           0              0.0

# %% [markdown]
# ## 5. Compare Column Names Across All Years

# %%
print("=" * 80)
print("COLUMN COMPARISON ACROSS ALL YEARS")
print("=" * 80)

# Get all unique column names
all_columns = set()
for year, df in dataframes.items():
    all_columns.update(df.columns)

all_columns = sorted(all_columns)

# Create comparison DataFrame
comparison_data = {'Column': all_columns}
for year in sorted(dataframes.keys()):
    comparison_data[f'In_{year}'] = [
        '✓' if col in dataframes[year].columns else '✗' 
        for col in all_columns
    ]

comparison_df = pd.DataFrame(comparison_data)
print("\nColumn presence across years:")
print(comparison_df.to_string(index=False))

# Check if all years have the same columns
print("\n" + "=" * 80)
print("Column Consistency Check:")
print("=" * 80)

base_year = sorted(dataframes.keys())[0]
base_columns = set(dataframes[base_year].columns)

all_same = True
for year in sorted(dataframes.keys())[1:]:
    year_columns = set(dataframes[year].columns)
    if base_columns != year_columns:
        all_same = False
        print(f"\n{year} differs from {base_year}:")
        only_in_base = base_columns - year_columns
        only_in_year = year_columns - base_columns
        if only_in_base:
            print(f"  Only in {base_year}: {only_in_base}")
        if only_in_year:
            print(f"  Only in {year}: {only_in_year}")

if all_same:
    print(f"\n✓ All years have the same columns ({len(base_columns)} columns)")
# Out:
# ================================================================================
# COLUMN COMPARISON ACROSS ALL YEARS
# ================================================================================
#
# Column presence across years:
#                              Column In_2020 In_2021 In_2022 In_2023 In_2024
#                     AREA CONSTRUIDA       ✓       ✓       ✓       ✓       ✓
#                        AREA TERRENO       ✓       ✓       ✓       ✓       ✓
#                                 CEP       ✓       ✓       ✓       ✓       ✓
#  CPF/CNPJ mascarado do contribuinte       ✓       ✓       ✓       ✓       ✓
#                   Código Logradouro       ✓       ✓       ✓       ✓       ✓
#              Número do contribuinte       ✓       ✓       ✓       ✓       ✓
#        Regime de Tributação da trsd       ✓       ✓       ✓       ✓       ✓
#        Regime de Tributação do iptu       ✓       ✓       ✓       ✓       ✓
#                  Tipo de Construção       ✓       ✓       ✓       ✓       ✓
#              Tipo de Empreendimento       ✓       ✓       ✓       ✓       ✓
#                   Tipo de Estrutura       ✓       ✓       ✓       ✓       ✓
#                                 _id       ✗       ✗       ✗       ✗       ✓
#         ano da construção corrigido       ✓       ✓       ✓       ✓       ✓
#                    ano do exercício       ✓       ✓       ✓       ✓       ✓
# ano e mês de início da contribuição       ✓       ✓       ✓       ✓       ✓
#                              bairro       ✓       ✓       ✓       ✓       ✓
#                              cidade       ✓       ✓       ✓       ✓       ✓
#                         complemento       ✓       ✓       ✓       ✓       ✓
#               data do cadastramento       ✓       ✓       ✓       ✓       ✓
#                              estado       ✓       ✓       ✓       ✓       ✓
#              fator de obsolescência       ✓       ✓       ✓       ✓       ✓
#                        fração ideal       ✓       ✓       ✓       ✓       ✓
#                          logradouro       ✓       ✓       ✓       ✓       ✓
#                              numero       ✓       ✓       ✓       ✓       ✓
#                    quant pavimentos       ✗       ✗       ✗       ✗       ✓
#            quantidade de pavimentos       ✓       ✓       ✓       ✓       ✗
#                tipo de contribuinte       ✓       ✓       ✓       ✓       ✓
#        tipo de padrão da construção       ✓       ✓       ✓       ✓       ✓
#               tipo de uso do imóvel       ✓       ✓       ✓       ✓       ✓
#                          valor IPTU       ✗       ✗       ✗       ✗       ✓
#               valor cobrado de IPTU       ✓       ✓       ✓       ✓       ✗
#           valor do m2 de construção       ✓       ✓       ✓       ✓       ✓
#              valor do m2 do terreno       ✓       ✓       ✓       ✓       ✓
#      valor total do imóvel estimado       ✓       ✓       ✓       ✓       ✓
#                        área ocupada       ✓       ✓       ✓       ✓       ✓
#
# ================================================================================
# Column Consistency Check:
# ================================================================================
#
# 2024 differs from 2020:
#   Only in 2020: {'quantidade de pavimentos', 'valor cobrado de IPTU'}
#   Only in 2024: {'quant pavimentos', 'valor IPTU', '_id'}

# %% [markdown]
# ## 6. Basic Statistics for Each Dataset

# %%
print("=" * 80)
print("BASIC STATISTICS FOR EACH DATASET")
print("=" * 80)

for year in sorted(dataframes.keys()):
    df = dataframes[year]
    print(f"\n{'='*80}")
    print(f"BASIC STATISTICS - IPTU {year}")
    print(f"{'='*80}")
    print(f"\nDataset Overview:")
    print(f"  Total rows: {len(df):,}")
    print(f"  Total columns: {len(df.columns)}")
    print(f"  Memory usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
    
    print(f"\nMissing Values Summary:")
    missing_summary = df.isnull().sum()
    missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
    if len(missing_summary) > 0:
        missing_df = pd.DataFrame({
            'Column': missing_summary.index,
            'Missing Count': missing_summary.values,
            'Missing Percentage': (missing_summary.values / len(df) * 100).round(2)
        })
        print(missing_df.to_string(index=False))
    else:
        print("  ✓ No missing values found")
    
    print(f"\nNumeric Columns Summary:")
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    if len(numeric_cols) > 0:
        print(df[numeric_cols].describe().to_string())
    else:
        print("  No numeric columns found")
    
    print(f"\nCategorical Columns (first 10):")
    categorical_cols = df.select_dtypes(include=['object']).columns[:10]
    if len(categorical_cols) > 0:
        for col in categorical_cols:
            unique_count = df[col].nunique()
            print(f"\n  {col}:")
            print(f"    Unique values: {unique_count}")
            if unique_count <= 20:
                print(f"    Values: {df[col].value_counts().head(10).to_dict()}")
            else:
                print(f"    Top 5 values: {df[col].value_counts().head(5).to_dict()}")
    print()
# Out:
# ================================================================================
# BASIC STATISTICS FOR EACH DATASET
# ================================================================================
#
# ================================================================================
# BASIC STATISTICS - IPTU 2020
# ================================================================================
#
# Dataset Overview:
#   Total rows: 403,915
#   Total columns: 32
#   Memory usage: 834.43 MB
#
# Missing Values Summary:
#   ✓ No missing values found
#
# Numeric Columns Summary:
#        ano do exercício         numero  ano da construção corrigido  quantidade de pavimentos  ano e mês de início da contribuição           CEP  Código Logradouro
# count          403915.0  403915.000000                403915.000000             403915.000000                        403915.000000  4.039150e+05      403915.000000
# mean             2020.0     541.768474                  1987.060869                  0.565097                        198767.937024  5.113046e+07       36596.305938
# std                 0.0     948.889888                    19.393033                  0.825026                          1935.555423  1.925287e+06       36240.840249
# min              2020.0      -1.000000                  1088.000000                 -1.000000                        190801.000000  0.000000e+00           0.000000
# 25%              2020.0      92.000000                  1978.000000                  1.000000                        198001.000000  5.075032e+07       16683.000000
# 50%              2020.0     224.000000                  1983.000000                  1.000000                        198508.000000  5.102113e+07       34371.000000
# 75%              2020.0     529.000000                  2002.000000                  1.000000                        200211.000000  5.204025e+07       53082.000000
# max              2020.0   50001.000000                  2024.000000                  1.000000                        202301.000000  5.249057e+07      900834.000000
#
# Categorical Columns (first 10):
#
#   Número do contribuinte:
#     Unique values: 80
#     Top 5 values: {'7*****0': 16411, '6*****0': 13899, '5*****0': 10323, '1*****0': 9810, '4*****0': 8709}
#
#   data do cadastramento:
#     Unique values: 94396
#     Top 5 values: {'1982/01/01 08:00:00.000000000': 67616, '1939/01/01 08:00:00.000000000': 9405, '1971/01/01 08:00:00.000000000': 6895, '1997/01/01 08:00:00.000000000': 5688, '1972/01/01 08:00:00.000000000': 5650}
#
#   tipo de contribuinte:
#     Unique values: 3
#     Values: {'1   ': 317204, '2   ': 49658, '    ': 37053}
#
#   CPF/CNPJ mascarado do contribuinte:
#     Unique values: 4080
#     Top 5 values: {'**.***.*      ': 37053, '10**.***.*00  ': 16076, '11**.***.*00  ': 7377, '00**.***.*00  ': 5096, '09**.***.*00  ': 3962}
#
#   logradouro:
#     Unique values: 6984
#     Top 5 values: {'AV BOA VIAGEM                                          ': 6531, 'AV CONS AGUIAR                                         ': 4405, 'AV RECIFE                                              ': 3197, 'RUA DOS NAVEGANTES                                     ': 3050, 'AV ENG DOMINGOS FERREIRA                               ': 2872}
#
#   complemento:
#     Unique values: 184046
#     Top 5 values: {'                                                                                                    ': 145101, 'CASA 0000                                                                                           ': 2657, 'CASA 000A                                                                                           ': 2234, 'APTO 0101                                                                                           ': 1059, 'APTO 0001                                                                                           ': 1035}
#
#   bairro:
#     Unique values: 93
#     Top 5 values: {'BOA VIAGEM          ': 67273, 'BOA VISTA           ': 13834, 'VARZEA              ': 13823, 'IMBIRIBEIRA         ': 13604, 'CASA AMARELA        ': 13176}
#
#   cidade:
#     Unique values: 1
#     Values: {'RECIFE                                  ': 403915}
#
#   estado:
#     Unique values: 1
#     Values: {'PE                            ': 403915}
#
#   fração ideal:
#     Unique values: 7261
#     Top 5 values: {'1,0   ': 123431, '0,1666': 4516, '0,25  ': 3082, '0,0034': 2910, '0,0312': 2842}
#
#
# ================================================================================
# BASIC STATISTICS - IPTU 2021
# ================================================================================
#
# Dataset Overview:
#   Total rows: 407,245
#   Total columns: 32
#   Memory usage: 841.34 MB
#
# Missing Values Summary:
#   ✓ No missing values found
#
# Numeric Columns Summary:
#        ano do exercício         numero  ano da construção corrigido  quantidade de pavimentos  ano e mês de início da contribuição           CEP  Código Logradouro
# count          407245.0  407245.000000                407245.000000             407245.000000                        407245.000000  4.072450e+05      407245.000000
# mean             2021.0     541.671583                  1987.324689                  0.552436                        198794.874552  5.113075e+07       36593.854095
# std                 0.0     948.426208                    19.539557                  0.833556                          1950.671104  1.918404e+06       36136.540892
# min              2021.0      -1.000000                  1088.000000                 -1.000000                        190801.000000  0.000000e+00           0.000000
# 25%              2021.0      92.000000                  1979.000000                  1.000000                        198001.000000  5.075022e+07       16756.000000
# 50%              2021.0     225.000000                  1984.000000                  1.000000                        198512.000000  5.102113e+07       34371.000000
# 75%              2021.0     530.000000                  2002.000000                  1.000000                        200304.000000  5.204025e+07       52930.000000
# max              2021.0   50001.000000                  2024.000000                  1.000000                        202301.000000  5.249057e+07      900834.000000
#
# Categorical Columns (first 10):
#
#   Número do contribuinte:
#     Unique values: 80
#     Top 5 values: {'7*****0': 16498, '6*****0': 13901, '5*****0': 10323, '1*****0': 9812, '4*****0': 8711}
#
#   data do cadastramento:
#     Unique values: 97622
#     Top 5 values: {'1982/01/01 08:00:00.000000000': 67616, '1939/01/01 08:00:00.000000000': 9405, '1971/01/01 08:00:00.000000000': 6895, '1997/01/01 08:00:00.000000000': 5690, '1972/01/01 08:00:00.000000000': 5652}
#
#   tipo de contribuinte:
#     Unique values: 3
#     Values: {'1   ': 319499, '2   ': 50693, '    ': 37053}
#
#   CPF/CNPJ mascarado do contribuinte:
#     Unique values: 4089
#     Top 5 values: {'**.***.*      ': 37053, '10**.***.*00  ': 16327, '11**.***.*00  ': 7416, '00**.***.*00  ': 5174, '09**.***.*00  ': 4016}
#
#   logradouro:
#     Unique values: 6988
#     Top 5 values: {'AV BOA VIAGEM                                          ': 6588, 'AV CONS AGUIAR                                         ': 4406, 'AV RECIFE                                              ': 3197, 'RUA DOS NAVEGANTES                                     ': 3050, 'AV ENG DOMINGOS FERREIRA                               ': 2873}
#
#   complemento:
#     Unique values: 186908
#     Top 5 values: {'                                                                                                    ': 145196, 'CASA 0000                                                                                           ': 2657, 'CASA 000A                                                                                           ': 2234, 'APTO 0101                                                                                           ': 1059, 'APTO 0001                                                                                           ': 1035}
#
#   bairro:
#     Unique values: 93
#     Top 5 values: {'BOA VIAGEM          ': 67748, 'VARZEA              ': 14410, 'BOA VISTA           ': 13963, 'IMBIRIBEIRA         ': 13750, 'CASA AMARELA        ': 13226}
#
#   cidade:
#     Unique values: 1
#     Values: {'RECIFE                                  ': 407245}
#
#   estado:
#     Unique values: 1
#     Values: {'PE                            ': 407245}
#
#   fração ideal:
#     Unique values: 7265
#     Top 5 values: {'1,0   ': 123531, '0,1666': 4528, '0,25  ': 3082, '0,0034': 2916, '0,0312': 2842}
#
#
# ================================================================================
# BASIC STATISTICS - IPTU 2022
# ================================================================================
#
# Dataset Overview:
#   Total rows: 411,090
#   Total columns: 32
#   Memory usage: 849.32 MB
#
# Missing Values Summary:
#   ✓ No missing values found
#
# Numeric Columns Summary:
#        ano do exercício         numero  ano da construção corrigido  quantidade de pavimentos  ano e mês de início da contribuição           CEP  Código Logradouro
# count          411090.0  411090.000000                411090.000000             411090.000000                        411090.000000  4.110900e+05      411090.000000
# mean             2022.0     542.593369                  1987.641966                  0.537965                        198826.860160  5.113151e+07       36683.947656
# std                 0.0     946.957440                    19.729599                  0.842968                          1969.307668  1.912015e+06       36031.379186
# min              2022.0      -1.000000                  1088.000000                 -1.000000                        190801.000000  0.000000e+00           0.000000
# 25%              2022.0      93.000000                  1979.000000                  1.000000                        198010.000000  5.075026e+07       16799.000000
# 50%              2022.0     227.000000                  1984.000000                  1.000000                        198606.000000  5.102113e+07       34576.000000
# 75%              2022.0     531.000000                  2003.000000                  1.000000                        200310.000000  5.204025e+07       53317.000000
# max              2022.0   50001.000000                  2024.000000                  1.000000                        202302.000000  5.249057e+07      900834.000000
#
# Categorical Columns (first 10):
#
#   Número do contribuinte:
#     Unique values: 80
#     Top 5 values: {'7*****0': 16621, '6*****0': 13901, '5*****0': 10322, '1*****0': 9811, '4*****0': 8709}
#
#   data do cadastramento:
#     Unique values: 101506
#     Top 5 values: {'1982/01/01 08:00:00.000000000': 67619, '1939/01/01 08:00:00.000000000': 9407, '1971/01/01 08:00:00.000000000': 6896, '1997/01/01 08:00:00.000000000': 5691, '1972/01/01 08:00:00.000000000': 5650}
#
#   tipo de contribuinte:
#     Unique values: 3
#     Values: {'1   ': 321973, '2   ': 52064, '    ': 37053}
#
#   CPF/CNPJ mascarado do contribuinte:
#     Unique values: 4099
#     Top 5 values: {'**.***.*      ': 37053, '10**.***.*00  ': 16369, '11**.***.*00  ': 7454, '00**.***.*00  ': 5203, '09**.***.*00  ': 4058}
#
#   logradouro:
#     Unique values: 6993
#     Top 5 values: {'AV BOA VIAGEM                                          ': 6592, 'AV CONS AGUIAR                                         ': 4414, 'AV RECIFE                                              ': 3199, 'RUA DOS NAVEGANTES                                     ': 3050, 'AV ENG DOMINGOS FERREIRA                               ': 2874}
#
#   complemento:
#     Unique values: 190287
#     Top 5 values: {'                                                                                                    ': 145265, 'CASA 0000                                                                                           ': 2657, 'CASA 000A                                                                                           ': 2234, 'APTO 0101                                                                                           ': 1059, 'APTO 0001                                                                                           ': 1035}
#
#   bairro:
#     Unique values: 93
#     Top 5 values: {'BOA VIAGEM          ': 68063, 'VARZEA              ': 14488, 'BOA VISTA           ': 14188, 'IMBIRIBEIRA         ': 13781, 'CASA AMARELA        ': 13312}
#
#   cidade:
#     Unique values: 1
#     Values: {'RECIFE                                  ': 411090}
#
#   estado:
#     Unique values: 1
#     Values: {'PE                            ': 411090}
#
#   fração ideal:
#     Unique values: 7266
#     Top 5 values: {'1,0   ': 123609, '0,1666': 4528, '0,25  ': 3083, '0,0034': 2911, '0,0312': 2874}
#
#
# ================================================================================
# BASIC STATISTICS - IPTU 2023
# ================================================================================
#
# Dataset Overview:
#   Total rows: 415,029
#   Total columns: 32
#   Memory usage: 857.52 MB
#
# Missing Values Summary:
#   ✓ No missing values found
#
# Numeric Columns Summary:
#        ano do exercício         numero  ano da construção corrigido  quantidade de pavimentos  ano e mês de início da contribuição           CEP  Código Logradouro
# count          415029.0  415029.000000                415029.000000             415029.000000                        415029.000000  4.150290e+05      415029.000000
# mean             2023.0     540.718649                  1987.971713                  0.523339                        198860.026372  5.113158e+07       36758.955259
# std                 0.0     945.020874                    19.926830                  0.852125                          1988.718020  1.903951e+06       36021.926249
# min              2023.0      -1.000000                  1088.000000                 -1.000000                        190801.000000  0.000000e+00           0.000000
# 25%              2023.0      92.000000                  1979.000000                  1.000000                        198012.000000  5.075023e+07       16829.000000
# 50%              2023.0     226.000000                  1985.000000                  1.000000                        198612.000000  5.102113e+07       34703.000000
# 75%              2023.0     529.000000                  2003.000000                  1.000000                        200403.000000  5.204025e+07       53317.000000
# max              2023.0   50001.000000                  2024.000000                  1.000000                        202312.000000  5.249057e+07      900834.000000
#
# Categorical Columns (first 10):
#
#   Número do contribuinte:
#     Unique values: 80
#     Top 5 values: {'7*****0': 16640, '6*****0': 13899, '5*****0': 10324, '1*****0': 9811, '4*****0': 8709}
#
#   data do cadastramento:
#     Unique values: 105429
#     Top 5 values: {'1982/01/01 08:00:00.000000000': 67619, '1939/01/01 08:00:00.000000000': 9404, '1971/01/01 08:00:00.000000000': 6896, '1997/01/01 08:00:00.000000000': 5689, '1972/01/01 08:00:00.000000000': 5651}
#
#   tipo de contribuinte:
#     Unique values: 3
#     Values: {'1   ': 323942, '2   ': 54034, '    ': 37053}
#
#   CPF/CNPJ mascarado do contribuinte:
#     Unique values: 4108
#     Top 5 values: {'**.***.*      ': 37053, '10**.***.*00  ': 17085, '11**.***.*00  ': 7605, '00**.***.*00  ': 5304, '09**.***.*00  ': 4068}
#
#   logradouro:
#     Unique values: 6997
#     Top 5 values: {'AV BOA VIAGEM                                          ': 6679, 'AV CONS AGUIAR                                         ': 4413, 'AV RECIFE                                              ': 3200, 'RUA DOS NAVEGANTES                                     ': 3051, 'AV ENG DOMINGOS FERREIRA                               ': 2880}
#
#   complemento:
#     Unique values: 193012
#     Top 5 values: {'                                                                                                    ': 145315, 'CASA 0000                                                                                           ': 2657, 'CASA 000A                                                                                           ': 2234, 'APTO 0101                                                                                           ': 1059, 'APTO 0001                                                                                           ': 1035}
#
#   bairro:
#     Unique values: 93
#     Top 5 values: {'BOA VIAGEM          ': 68573, 'VARZEA              ': 14752, 'BOA VISTA           ': 14188, 'IMBIRIBEIRA         ': 13755, 'CASA AMARELA        ': 13676}
#
#   cidade:
#     Unique values: 1
#     Values: {'RECIFE                                  ': 415029}
#
#   estado:
#     Unique values: 1
#     Values: {'PE                            ': 415029}
#
#   fração ideal:
#     Unique values: 7266
#     Top 5 values: {'1,0   ': 123655, '0,1666': 4535, '0,25  ': 3083, '0,0034': 2912, '0,0312': 2875}
#
#
# ================================================================================
# BASIC STATISTICS - IPTU 2024
# ================================================================================
#
# Dataset Overview:
#   Total rows: 500
#   Total columns: 33
#   Memory usage: 1.03 MB
#
# Missing Values Summary:
#   ✓ No missing values found
#
# Numeric Columns Summary:
#               _id  ano do exercício       numero  ano da construção corrigido  quant pavimentos  ano e mês de início da contribuição           CEP  Código Logradouro
# count  500.000000             500.0   500.000000                    500.00000         500.00000                           500.000000  5.000000e+02         500.000000
# mean   250.500000            2024.0   485.444000                   1981.22600           0.82800                        198260.832000  5.172064e+07       32899.816000
# std    144.481833               0.0   772.960801                     15.73627           0.56129                          1525.105442  2.385602e+06       54444.187508
# min      1.000000            2024.0    -1.000000                   1939.00000          -1.00000                        193901.000000  0.000000e+00         183.000000
# 25%    125.750000            2024.0    85.750000                   1980.75000           1.00000                        198201.000000  5.202090e+07        6874.000000
# 50%    250.500000            2024.0   253.000000                   1982.00000           1.00000                        198201.000000  5.213024e+07       30288.500000
# 75%    375.250000            2024.0   558.000000                   1982.00000           1.00000                        198508.750000  5.213032e+07       49042.000000
# max    500.000000            2024.0  6500.000000                   2024.00000           1.00000                        202402.000000  5.228051e+07      900834.000000
#
# Categorical Columns (first 10):
#
#   Número do contribuinte:
#     Unique values: 76
#     Top 5 values: {'2*****0': 62, '2*****7': 36, '2*****3': 36, '2*****6': 33, '2*****1': 31}
#
#   data do cadastramento:
#     Unique values: 172
#     Top 5 values: {'1982-01-01T08:00:00': 247, '1971-01-01T08:00:00': 14, '1952-01-01T08:00:00': 10, '1970-01-01T08:00:00': 7, '1969-01-01T08:00:00': 6}
#
#   tipo de contribuinte:
#     Unique values: 3
#     Values: {'1   ': 361, '    ': 114, '2   ': 25}
#
#   CPF/CNPJ mascarado do contribuinte:
#     Unique values: 289
#     Top 5 values: {'**.***.*      ': 114, '10**.***.*00  ': 14, '00**.***.*68  ': 8, '10**.***.*04  ': 6, '24**.***.*04  ': 5}
#
#   logradouro:
#     Unique values: 163
#     Top 5 values: {'AV ANIBAL BENEVOLO                                     ': 72, 'RUA PORTO REAL                                         ': 45, 'RUA MARAJO                                             ': 37, 'RUA LAGE GRANDE                                        ': 34, 'RUA VITORIANA                                          ': 32}
#
#   complemento:
#     Unique values: 150
#     Top 5 values: {'                                                                                                    ': 324, 'CASA 000A                                                                                           ': 8, 'CASA 0000                                                                                           ': 7, 'CASA 000B                                                                                           ': 6, 'BLOCO A                                                                                             ': 3}
#
#   bairro:
#     Unique values: 53
#     Top 5 values: {'BEBERIBE            ': 225, 'LINHA DO TIRO       ': 74, 'BOA VIAGEM          ': 30, 'AGUA FRIA           ': 25, 'CASA AMARELA        ': 12}
#
#   cidade:
#     Unique values: 1
#     Values: {'RECIFE                                  ': 500}
#
#   estado:
#     Unique values: 1
#     Values: {'PE                            ': 500}
#
#   fração ideal:
#     Unique values: 147
#     Top 5 values: {'1,0   ': 321, '0,1168': 5, '0,5   ': 5, '0,1622': 5, '0,3333': 4}

# %% [markdown]
# ## 7. Sample Data from Each Dataset

# %%
print("=" * 80)
print("SAMPLE DATA FROM EACH DATASET (First 5 rows)")
print("=" * 80)

for year in sorted(dataframes.keys()):
    df = dataframes[year]
    print(f"\n{'='*80}")
    print(f"SAMPLE DATA - IPTU {year}")
    print(f"{'='*80}")
    print(df.head(5).to_string())
    print()
# Out:
# ================================================================================
# SAMPLE DATA FROM EACH DATASET (First 5 rows)
# ================================================================================
#
# ================================================================================
# SAMPLE DATA - IPTU 2020
# ================================================================================
#   Número do contribuinte  ano do exercício          data do cadastramento tipo de contribuinte CPF/CNPJ mascarado do contribuinte                                               logradouro  numero                                                                                           complemento                bairro                                    cidade                          estado fração ideal AREA TERRENO AREA CONSTRUIDA área ocupada valor do m2 do terreno valor do m2 de construção  ano da construção corrigido  quantidade de pavimentos           tipo de uso do imóvel    tipo de padrão da construção fator de obsolescência  ano e mês de início da contribuição valor total do imóvel estimado valor cobrado de IPTU       CEP                        Regime de Tributação do iptu                                                                          Regime de Tributação da trsd              Tipo de Construção          Tipo de Empreendimento               Tipo de Estrutura  Código Logradouro
# 0                3*****1              2020  1996/05/30 08:00:00.000000000                 1                        75**.***.*00    RUA AFONSO CELSO                                            182  APTO 1201 EDF TIPUANA                                                                                 TAMARINEIRA           RECIFE                                    PE                                   0,0333    1041,89         120,0        196,74                   7017,9                  1265,91                           1996                         1  RESIDENCIAL                     Médio                                          0,936                                199605                    240273,14             2402,73      52060110  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Concreto                                     1015
# 1                6*****0              2020  2002/06/12 08:00:00.000000000                 2                        11**.***.*00    RUA JEAN MERMOZ                                              47  APTO 0601 EDF JOHAN MORITZ                                                                            BOA VIAGEM            RECIFE                                    PE                                   0,1666    564,0           436,33       436,33                   38829,3                 1613,93                           2002                         1  RESIDENCIAL                     Superior                                       0,964                                200206                    773600,12             9283,2       51130330  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Concreto                                    32930
# 2                7*****3              2020  2014/01/29 11:15:30.530000000                 1                        40**.***.*53    AV PROF JOSE DOS ANJOS                                      110  APTO 1103 EDF NAPOLES                                                                                 CASA AMARELA          RECIFE                                    PE                                   0,0208    1217,3          74,08        104,1                    1249,43                 1265,91                           2014                        -1  RESIDENCIAL                     Médio                                          0,996                                201406                    132328,45             1058,63      52051345  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Alvenaria                                   35270
# 3                1*****5              2020  1982/01/01 08:00:00.000000000                 1                        03**.***.*89    RUA DR JOSE MARIANO                                         773                                                                                                        COELHOS               RECIFE                                    PE                                   0,0526    180,0           30,0         30,0                     7017,9                  427,5                             1982                         1  COMERCIAL COM LIXO ORGANICO     Simples                                        0,2099                               198201                    15971,35              159,71       50060315  Normal                                              Normal                                                                                                Casa                            Casa                            Taipa/adobe                                 36234
# 4                6*****0              2020  1969/01/01 08:00:00.000000000                 1                        36**.***.*53    AV CONS AGUIAR                                             3493  APTO 0101 EDF DIMONA                                                                                  BOA VIAGEM            RECIFE                                    PE                                   0,1833    487,5           184,8        184,8                    35166,1                 598,58                            1969                         1  RESIDENCIAL                     Médio                                          0,711                                196901                    171872,84             1374,98      51020021  Normal                                              Normal                                                                                                Apartamento <= 4 Pavimentos     Apartamento                     Concreto                                     1465
#
#
# ================================================================================
# SAMPLE DATA - IPTU 2021
# ================================================================================
#   Número do contribuinte  ano do exercício          data do cadastramento tipo de contribuinte CPF/CNPJ mascarado do contribuinte                                               logradouro  numero                                                                                           complemento                bairro                                    cidade                          estado fração ideal AREA TERRENO AREA CONSTRUIDA área ocupada valor do m2 do terreno valor do m2 de construção  ano da construção corrigido  quantidade de pavimentos           tipo de uso do imóvel    tipo de padrão da construção fator de obsolescência  ano e mês de início da contribuição valor total do imóvel estimado valor cobrado de IPTU       CEP                        Regime de Tributação do iptu                                                                          Regime de Tributação da trsd              Tipo de Construção          Tipo de Empreendimento               Tipo de Estrutura  Código Logradouro
# 0                4*****3              2021  1967/01/01 08:00:00.000000000                 1                        23**.***.*53    RUA OCIDENTAL                                                33                                                                                                        CORDEIRO              RECIFE                                    PE                                   1,0       450,0           229,03       229,03                   1298,41                 444,26                            1967                         1  RESIDENCIAL                     Simples                                        0,676                                196701                    88258,38              0,0          50721610  Isenção- Utilização pelo Poder Público Municipal    Isenção- Utilização pelo Poder Público Municipal                                                      Casa                            Casa                            Alvenaria                                   47104
# 1                1*****6              2021  1972/01/01 08:00:00.000000000                 2                        11**.***.*00    RUA DA CONCORDIA                                            984                                                                                                        SAO JOSE              RECIFE                                    PE                                   1,0       543,73          1055,47      1055,47                  44158,2                 1114,22                           1972                         1  COMERCIAL COM LIXO ORGANICO     Superior                                       0,7332                               197201                    1642537,49            0,0          50020055  Isenção - Sede Própria - Agremiação Carnavalesca    Isenção - Imóvel Sede Agremiação Carnavalesca                                                         Edificação Especial             Edificação Especial             Alvenaria                                   17264
# 2                7*****1              2021  2010/05/12 13:03:12.726000000                 2                        61**.***.*00    RUA DR GEORGE WILLIAM BUTLER                                675                                                                                                        CURADO                RECIFE                                    PE                                   1,0       103057,83       49997,37     49997,37                 1298,41                 888,98                            2002                         1  COMERCIAL COM LIXO ORGANICO     Médio                                          0,9599                               201001                    43286509,96           865730,2     50950015  Normal                                              Normal                                                                                                Edificação Industrial           Industria                       Alvenaria                                   84751
# 3                6*****6              2021  2002/06/25 08:00:00.000000000                 1                        19**.***.*20    RUA AGENOR LOPES                                            424  APTO 0901 EDF SÃO FRANCISCO DE PAULA                                                                  BOA VIAGEM            RECIFE                                    PE                                   0,0192    1710,76         95,27        195,73                   3906,97                 1496,38                           2002                         1  RESIDENCIAL                     Superior                                       0,9599                               200206                    283056,05             2830,56      51021110  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Concreto                                     1180
# 4                6*****3              2021  2000/01/26 08:00:00.000000000                 1                        12**.***.*15    AV FERNANDO SIMOES BARBOSA                                  348  APTO 1302 EDF SAINT PAUL                                                                              BOA VIAGEM            RECIFE                                    PE                                   0,0166    1920,0          215,53       215,53                   18753,0                 1444,36                           2000                         1  RESIDENCIAL                     Superior                                       0,951                                200001                    309366,43             3093,66      51020390  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Concreto                                    24228
#
#
# ================================================================================
# SAMPLE DATA - IPTU 2022
# ================================================================================
#   Número do contribuinte  ano do exercício          data do cadastramento tipo de contribuinte CPF/CNPJ mascarado do contribuinte                                               logradouro  numero                                                                                           complemento                bairro                                    cidade                          estado fração ideal AREA TERRENO AREA CONSTRUIDA área ocupada valor do m2 do terreno valor do m2 de construção  ano da construção corrigido  quantidade de pavimentos           tipo de uso do imóvel    tipo de padrão da construção fator de obsolescência  ano e mês de início da contribuição valor total do imóvel estimado valor cobrado de IPTU       CEP                        Regime de Tributação do iptu                                                                          Regime de Tributação da trsd              Tipo de Construção          Tipo de Empreendimento               Tipo de Estrutura  Código Logradouro
# 0                7*****7              2022  2018/09/17 13:48:06.019000000                 1                        23**.***.*20    RUA DO CUPIM                                                228  APTO 807 EDF STUDIO GRAÇAS                                                                            GRACAS                RECIFE                                    PE                                   0,0143    1098,0          31,12        54,92                    17561,2                 1455,9                            2018                        -1  RESIDENCIAL                     Médio                                          0,9982                               201808                    87517,2               700,14       52011070  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Concreto                                    18708
# 1                7*****3              2022  2018/09/17 13:48:07.519000000                 1                        09**.***.*72    RUA DO CUPIM                                                228  APTO 901 EDF STUDIO GRAÇAS                                                                            GRACAS                RECIFE                                    PE                                   0,0143    1098,0          31,1         54,89                    17561,2                 1455,9                            2018                        -1  RESIDENCIAL                     Médio                                          0,9982                               201808                    87468,23              699,75       52011070  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Concreto                                    18708
# 2                7*****7              2022  2018/09/17 13:48:08.119000000                 1                        36**.***.*20    RUA DO CUPIM                                                228  APTO 902 EDF STUDIO GRAÇAS                                                                            GRACAS                RECIFE                                    PE                                   0,0143    1098,0          31,12        54,92                    17561,2                 1455,9                            2018                        -1  RESIDENCIAL                     Médio                                          0,9982                               201808                    87517,2               700,14       52011070  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Concreto                                    18708
# 3                5*****8              2022  1987/06/22 08:00:00.000000000                 1                        00**.***.*68    RUA IBITIGUARA                                              295                                                                                                        COHAB                 RECIFE                                    PE                                   1,0       70,0            25,0         25,0                     375,27                  491,66                            1979                         1  RESIDENCIAL                     Simples                                        0,1731                               198706                    3441,11               20,65        51330250  Normal                                              Normal                                                                                                Casa                            Casa                            Taipa/adobe                                 81078
# 4                7*****5              2022  2018/09/17 13:48:06.842000000                 2                        11**.***.*00    RUA DO CUPIM                                                228  APTO 808 EDF STUDIO GRAÇAS                                                                            GRACAS                RECIFE                                    PE                                   0,0143    1098,0          31,1         54,89                    17561,2                 1455,9                            2018                        -1  RESIDENCIAL                     Médio                                          0,9982                               201808                    87468,23              699,75       52011070  Normal                                              Normal                                                                                                Apartamento > 4 Pavimentos      Apartamento                     Concreto                                    18708
#
#
# ================================================================================
# SAMPLE DATA - IPTU 2023
# ================================================================================
#   Número do contribuinte  ano do exercício          data do cadastramento tipo de contribuinte CPF/CNPJ mascarado do contribuinte                                               logradouro  numero                                                                                           complemento                bairro                                    cidade                          estado fração ideal AREA TERRENO AREA CONSTRUIDA área ocupada valor do m2 do terreno valor do m2 de construção  ano da construção corrigido  quantidade de pavimentos           tipo de uso do imóvel    tipo de padrão da construção fator de obsolescência  ano e mês de início da contribuição valor total do imóvel estimado valor cobrado de IPTU       CEP                        Regime de Tributação do iptu                                                                          Regime de Tributação da trsd              Tipo de Construção          Tipo de Empreendimento               Tipo de Estrutura  Código Logradouro
# 0                2*****4              2023  1982/06/17 08:00:00.000000000                 1                        07**.***.*53    AV BEBERIBE                                                3530  APTO 0202 BLOCO A14                                                                                   PORTO DA MADEIRA      RECIFE                                    PE                                   0,0016    70650,0         87,08        87,08                    2549,63                 625,06                            1982                         1  RESIDENCIAL                     Simples                                        0,8132                               198206                    45485,99              272,92       52130547  Normal                                              Normal                                                                                                Apartamento <= 4 Pavimentos     Apartamento                     Alvenaria                                   10529
# 1                2*****2              2023  1982/06/17 08:00:00.000000000                 1                        04**.***.*20    AV BEBERIBE                                                3530  APTO 0203 BLOCO A14                                                                                   PORTO DA MADEIRA      RECIFE                                    PE                                   0,0016    70650,0         87,08        87,08                    2549,63                 625,06                            1982                         1  RESIDENCIAL                     Simples                                        0,8132                               198206                    45485,99              272,92       52130547  Normal                                              Normal                                                                                                Apartamento <= 4 Pavimentos     Apartamento                     Alvenaria                                   10529
# 2                2*****0              2023  1982/06/17 08:00:00.000000000                 1                        00**.***.*58    AV BEBERIBE                                                3530  APTO 0204 BLOCO A14                                                                                   PORTO DA MADEIRA      RECIFE                                    PE                                   0,0016    70650,0         87,08        87,08                    2549,63                 625,06                            1982                         1  RESIDENCIAL                     Simples                                        0,8132                               198206                    45485,99              272,92       52130547  Normal                                              Normal                                                                                                Apartamento <= 4 Pavimentos     Apartamento                     Alvenaria                                   10529
# 3                2*****9              2023  1982/06/17 08:00:00.000000000                 1                        11**.***.*20    AV BEBERIBE                                                3530  APTO 0301 BLOCO A14                                                                                   PORTO DA MADEIRA      RECIFE                                    PE                                   0,0016    70650,0         87,08        87,08                    2549,63                 625,06                            1982                         1  COMERCIAL COM LIXO ORGANICO     Simples                                        0,8132                               198206                    45485,99              454,86       52130547  Normal                                              Normal                                                                                                Apartamento <= 4 Pavimentos     Apartamento                     Alvenaria                                   10529
# 4                7*****1              2023  2007/04/18 10:40:54.421000000                 1                        17**.***.*34    RUA CERAIMA                                                  89                                                                                                        BONGI                 RECIFE                                    PE                                   1,0       126,64          89,89        89,89                    1834,61                 523,47                            1967                        -1  RESIDENCIAL                     Simples                                        0,6516                               200801                    39870,59              239,22       50751500  Normal                                              Normal                                                                                                Casa                            Casa                            Alvenaria                                   16799
#
#
# ================================================================================
# SAMPLE DATA - IPTU 2024
# ================================================================================
#    _id Número do contribuinte  ano do exercício data do cadastramento tipo de contribuinte CPF/CNPJ mascarado do contribuinte                                               logradouro  numero                                                                                           complemento                bairro                                    cidade                          estado fração ideal AREA TERRENO AREA CONSTRUIDA área ocupada valor do m2 do terreno valor do m2 de construção  ano da construção corrigido  quant pavimentos           tipo de uso do imóvel    tipo de padrão da construção fator de obsolescência  ano e mês de início da contribuição valor total do imóvel estimado   valor IPTU       CEP                        Regime de Tributação do iptu                                                                          Regime de Tributação da trsd              Tipo de Construção          Tipo de Empreendimento               Tipo de Estrutura  Código Logradouro
# 0    1                2*****2              2024   1971-01-01T08:00:00                 1                        02**.***.*30    RUA LAGE GRANDE                                             156  CASA 0000                                                                                             LINHA DO TIRO         RECIFE                                    PE                                   1,0       96,0            65,8         65,8                     771,93                  548,7                             1971                 1  RESIDENCIAL                     Simples                                        0,6416                               197101                    26383,57     158,3        52131400  Normal                                              Normal                                                                                                Casa                            Casa                            Alvenaria                                   37826
# 1    2                2*****6              2024   1970-01-01T08:00:00                 1                        40**.***.*72    RUA LAGE GRANDE                                             150                                                                                                        LINHA DO TIRO         RECIFE                                    PE                                   1,0       140,0           116,37       116,37                   771,93                  611,49                            1970                 1  RESIDENCIAL                     Simples                                        0,6698                               197001                    51985,17     311,91       52131400  Normal                                              Normal                                                                                                Casa                            Casa                            Alvenaria                                   37826
# 2    3                2*****4              2024   1961-01-01T08:00:00                 1                        25**.***.*49    RUA LAGE GRANDE                                             156                                                                                                        LINHA DO TIRO         RECIFE                                    PE                                   1,0       80,0            43,0         43,0                     771,93                  548,7                             1961                 1  RESIDENCIAL                     Simples                                        0,6                                  196101                    17244,18     103,47       52131400  Normal                                              Normal                                                                                                Casa                            Casa                            Alvenaria                                   37826
# 3    4                2*****2              2024   1982-01-01T08:00:00                 1                        41**.***.*34    RUA LAGE GRANDE                                             168  CASA 0000                                                                                             LINHA DO TIRO         RECIFE                                    PE                                   1,0       130,0           29,0         29,0                     771,93                  548,7                             1982                 1  RESIDENCIAL                     Simples                                        0,804                                198201                    16923,32     101,54       52131400  Normal                                              Normal                                                                                                Casa                            Casa                            Alvenaria                                   37826
# 4    5                2*****0              2024   1982-01-01T08:00:00                 1                        02**.***.*04    RUA LAGE GRANDE                                             152                                                                                                        LINHA DO TIRO         RECIFE                                    PE                                   1,0       0,0             43,0         43,0                     771,93                  548,7                             1982                 1  RESIDENCIAL                     Simples                                        0,804                                198201                    23215,28     139,29       52131400  Normal                                              Normal                                                                                                Casa                            Casa                            Alvenaria                                   37826

# %% [markdown]
# ## 8. Data Quality Checks

# %%
print("=" * 80)
print("DATA QUALITY CHECKS")
print("=" * 80)

for year in sorted(dataframes.keys()):
    df = dataframes[year]
    print(f"\n{'='*80}")
    print(f"DATA QUALITY - IPTU {year}")
    print(f"{'='*80}")
    
    # Duplicate rows
    duplicates = df.duplicated().sum()
    print(f"\nDuplicate rows: {duplicates:,} ({duplicates/len(df)*100:.2f}%)")
    
    # Check for potential ID column
    id_cols = [col for col in df.columns if 'id' in col.lower() or '_id' in col.lower()]
    if id_cols:
        print(f"\nPotential ID columns: {id_cols}")
        for col in id_cols:
            unique_count = df[col].nunique()
            print(f"  {col}: {unique_count:,} unique values out of {len(df):,} rows")
    
    # Check date columns
    date_cols = [col for col in df.columns if 'data' in col.lower() or 'ano' in col.lower() or 'timestamp' in col.lower()]
    if date_cols:
        print(f"\nDate/Year columns: {date_cols}")
    
    # Check for empty strings
    empty_strings = {}
    for col in df.select_dtypes(include=['object']).columns:
        empty_count = (df[col] == '').sum()
        if empty_count > 0:
            empty_strings[col] = empty_count
    
    if empty_strings:
        print(f"\nColumns with empty strings:")
        for col, count in sorted(empty_strings.items(), key=lambda x: x[1], reverse=True):
            print(f"  {col}: {count:,} ({count/len(df)*100:.2f}%)")
    
    print()
# Out:
# ================================================================================
# DATA QUALITY CHECKS
# ================================================================================
#
# ================================================================================
# DATA QUALITY - IPTU 2020
# ================================================================================
#
# Duplicate rows: 60 (0.01%)
#
# Potential ID columns: ['cidade', 'fração ideal', 'AREA CONSTRUIDA', 'ano da construção corrigido', 'quantidade de pavimentos']
#   cidade: 1 unique values out of 403,915 rows
#   fração ideal: 7,261 unique values out of 403,915 rows
#   AREA CONSTRUIDA: 36,912 unique values out of 403,915 rows
#   ano da construção corrigido: 106 unique values out of 403,915 rows
#   quantidade de pavimentos: 2 unique values out of 403,915 rows
#
# Date/Year columns: ['ano do exercício', 'data do cadastramento', 'ano da construção corrigido', 'ano e mês de início da contribuição']
#
#
# ================================================================================
# DATA QUALITY - IPTU 2021
# ================================================================================
#
# Duplicate rows: 60 (0.01%)
#
# Potential ID columns: ['cidade', 'fração ideal', 'AREA CONSTRUIDA', 'ano da construção corrigido', 'quantidade de pavimentos']
#   cidade: 1 unique values out of 407,245 rows
#   fração ideal: 7,265 unique values out of 407,245 rows
#   AREA CONSTRUIDA: 36,964 unique values out of 407,245 rows
#   ano da construção corrigido: 106 unique values out of 407,245 rows
#   quantidade de pavimentos: 2 unique values out of 407,245 rows
#
# Date/Year columns: ['ano do exercício', 'data do cadastramento', 'ano da construção corrigido', 'ano e mês de início da contribuição']
#
#
# ================================================================================
# DATA QUALITY - IPTU 2022
# ================================================================================
#
# Duplicate rows: 60 (0.01%)
#
# Potential ID columns: ['cidade', 'fração ideal', 'AREA CONSTRUIDA', 'ano da construção corrigido', 'quantidade de pavimentos']
#   cidade: 1 unique values out of 411,090 rows
#   fração ideal: 7,266 unique values out of 411,090 rows
#   AREA CONSTRUIDA: 37,009 unique values out of 411,090 rows
#   ano da construção corrigido: 106 unique values out of 411,090 rows
#   quantidade de pavimentos: 2 unique values out of 411,090 rows
#
# Date/Year columns: ['ano do exercício', 'data do cadastramento', 'ano da construção corrigido', 'ano e mês de início da contribuição']
#
#
# ================================================================================
# DATA QUALITY - IPTU 2023
# ================================================================================
#
# Duplicate rows: 60 (0.01%)
#
# Potential ID columns: ['cidade', 'fração ideal', 'AREA CONSTRUIDA', 'ano da construção corrigido', 'quantidade de pavimentos']
#   cidade: 1 unique values out of 415,029 rows
#   fração ideal: 7,266 unique values out of 415,029 rows
#   AREA CONSTRUIDA: 37,072 unique values out of 415,029 rows
#   ano da construção corrigido: 106 unique values out of 415,029 rows
#   quantidade de pavimentos: 2 unique values out of 415,029 rows
#
# Date/Year columns: ['ano do exercício', 'data do cadastramento', 'ano da construção corrigido', 'ano e mês de início da contribuição']
#
#
# ================================================================================
# DATA QUALITY - IPTU 2024
# ================================================================================
#
# Duplicate rows: 0 (0.00%)
#
# Potential ID columns: ['_id', 'cidade', 'fração ideal', 'AREA CONSTRUIDA', 'ano da construção corrigido']
#   _id: 500 unique values out of 500 rows
#   cidade: 1 unique values out of 500 rows
#   fração ideal: 147 unique values out of 500 rows
#   AREA CONSTRUIDA: 258 unique values out of 500 rows
#   ano da construção corrigido: 76 unique values out of 500 rows
#
# Date/Year columns: ['ano do exercício', 'data do cadastramento', 'ano da construção corrigido', 'ano e mês de início da contribuição']

# %% [markdown]
# ## 9. Summary and Next Steps

# %%
print("=" * 80)
print("SUMMARY - ALL DATASETS")
print("=" * 80)

summary_data = []
for year in sorted(dataframes.keys()):
    df = dataframes[year]
    summary_data.append({
        'Year': year,
        'Rows': f"{len(df):,}",
        'Columns': len(df.columns),
        'Memory (MB)': f"{df.memory_usage(deep=True).sum() / 1024**2:.2f}",
        'Missing Values': df.isnull().sum().sum(),
        'Duplicate Rows': df.duplicated().sum()
    })

summary_df = pd.DataFrame(summary_data)
print("\nOverview of all datasets:")
print(summary_df.to_string(index=False))

print("\n" + "=" * 80)
print("All schemas have been printed above for detailed review.")
print("=" * 80)
# Out:
# ================================================================================
# SUMMARY - ALL DATASETS
# ================================================================================
#
# Overview of all datasets:
#  Year    Rows  Columns Memory (MB)  Missing Values  Duplicate Rows
#  2020 403,915       32      841.16               0              60
#  2021 407,245       32      848.19               0              60
#  2022 411,090       32      856.31               0              60
#  2023 415,029       32      864.79               0              60
#  2024     500       33        1.03               0               0
#
# ================================================================================
# All schemas have been printed above for detailed review.
# ================================================================================
